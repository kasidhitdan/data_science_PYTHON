# %%
import pandas as pd
pd.__version__
# Out:
# '1.5.3'

# %%
#Read data from a CSV file into the variable df
df = pd.read_csv('..\data\movies_metadata.csv')

#Display the data in tabular format
df.head()
# Out:
# C:\Users\kasid\AppData\Local\Temp\ipykernel_28656\1701533626.py:1: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('..\data\movies_metadata.csv')
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
# ...

# %%
#Display shape of dataframe
df.shape
# Out:
# (45466, 24)

# %%
#Display all the columns in the dataframe
df.columns
# Out:
# Index(['adult', 'belongs_to_collection', 'budget', 'genres', 'homepage', 'id',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title', 'video',
#        'vote_average', 'vote_count'],
#       dtype='object')

# %%
#Select the data in row 2 of df
second = df.iloc[1]
second
# Out:
# adult                                                                False
# belongs_to_collection                                                  NaN
# budget                                                            65000000
# genres                   [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# homepage                                                               NaN
# id                                                                    8844
# imdb_id                                                          tt0113497
# original_language                                                       en
# original_title                                                     Jumanji
# overview                 When siblings Judy and Peter discover an encha...
# popularity                                                       17.015539
# poster_path                               /vzmL6fP7aPKNKPRTFnZmiUfciyV.jpg
# ...

# %%
#Change the index using the title
df = df.set_index('title')
#Access data by referring to the title
mymovie = df.loc['Jumanji']
mymovie
# Out:
# adult                                                                False
# belongs_to_collection                                                  NaN
# budget                                                            65000000
# genres                   [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# homepage                                                               NaN
# id                                                                    8844
# imdb_id                                                          tt0113497
# original_language                                                       en
# original_title                                                     Jumanji
# overview                 When siblings Judy and Peter discover an encha...
# popularity                                                       17.015539
# poster_path                               /vzmL6fP7aPKNKPRTFnZmiUfciyV.jpg
# ...

# %%
df = df.reset_index()

# %%
#Create a smaller DataFrame as a subset of the original df
small_df =df[['title','release_date','budget','revenue','runtime','genres']]
#Display the data in tabular format of small_df
small_df.head(15)
# Out:
#                           title release_date    budget      revenue  runtime  \
# 0                     Toy Story   1995-10-30  30000000  373554033.0     81.0
# 1                       Jumanji   1995-12-15  65000000  262797249.0    104.0
# 2              Grumpier Old Men   1995-12-22         0          0.0    101.0
# 3             Waiting to Exhale   1995-12-22  16000000   81452156.0    127.0
# 4   Father of the Bride Part II   1995-02-10         0   76578911.0    106.0
# 5                          Heat   1995-12-15  60000000  187436818.0    170.0
# 6                       Sabrina   1995-12-15  58000000          0.0    127.0
# 7                  Tom and Huck   1995-12-22         0          0.0     97.0
# 8                  Sudden Death   1995-12-22  35000000   64350171.0    106.0
# 9                     GoldenEye   1995-11-16  58000000  352194034.0    130.0
# 10       The American President   1995-11-17  62000000  107879496.0    106.0
# ...

# %%
#Check the data types of the dataframe
small_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45466 entries, 0 to 45465
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   title         45460 non-null  object
#  1   release_date  45379 non-null  object
#  2   budget        45466 non-null  object
#  3   revenue       45460 non-null  float64
#  4   runtime       45203 non-null  float64
#  5   genres        45466 non-null  object
# dtypes: float64(2), object(4)
# memory usage: 2.1+ MB

# %%
#Import the numpy library 
import numpy as np
#Create a function to check values and convert them to float
def to_float(x) :
    try:
        x = float(x)
    except:
        x = np.nan
    return x
#Use the apply method to check and convert every value in the budget column using the to_float() function
small_df['budget'] = small_df['budget'].apply(to_float)
#Convert the data type of the budget column to float
small_df['budget'] = small_df['budget'].astype('float')
#Check data type from column
small_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45466 entries, 0 to 45465
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   title         45460 non-null  object
#  1   release_date  45379 non-null  object
#  2   budget        45463 non-null  float64
#  3   revenue       45460 non-null  float64
#  4   runtime       45203 non-null  float64
#  5   genres        45466 non-null  object
# dtypes: float64(3), object(3)
# memory usage: 2.1+ MB
# C:\Users\kasid\AppData\Local\Temp\ipykernel_28656\1854207819.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   small_df['budget'] = small_df['budget'].apply(to_float)
# ...

# %%
#Convert release_date to pandas datetime format first
small_df['release_date'] =pd.to_datetime(small_df['release_date'], errors='coerce')
#Extract the year data from release_date to create a new column named 'year'
small_df['year'] = small_df['release_date'].apply(lambda x:
str(x).split('-')[0] if x != np.nan else np.nan)
#Display the data in tabular format of small_df.
small_df.head()
# Out:
# C:\Users\kasid\AppData\Local\Temp\ipykernel_28656\1565215559.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   small_df['release_date'] =pd.to_datetime(small_df['release_date'], errors='coerce')
# C:\Users\kasid\AppData\Local\Temp\ipykernel_28656\1565215559.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   small_df['year'] = small_df['release_date'].apply(lambda x:
#                          title release_date      budget      revenue  runtime  \
# ...

# %%
#Arrange the data of movies by using the 'year' column
small_df = small_df.sort_values('year')
#Display the data in tabular format of small_df
small_df.head()
# Out:
#                                title release_date  budget  revenue  runtime  \
# 34940               Passage of Venus   1874-12-09     0.0      0.0      1.0
# 34937     Sallie Gardner at a Gallop   1878-06-14     0.0      0.0      1.0
# 41602                Buffalo Running   1883-11-19     0.0      0.0      1.0
# 34933    Man Walking Around a Corner   1887-08-18     0.0      0.0      1.0
# 34938  Traffic Crossing Leeds Bridge   1888-10-15     0.0      0.0      1.0
#
#                                     genres  year
# 34940  [{'id': 99, 'name': 'Documentary'}]  1874
# 34937  [{'id': 99, 'name': 'Documentary'}]  1878
# 41602  [{'id': 99, 'name': 'Documentary'}]  1883
# 34933  [{'id': 99, 'name': 'Documentary'}]  1887
# 34938  [{'id': 99, 'name': 'Documentary'}]  1888

# %%
#Select movies that have generated revenue greater than 1 billion dollars and have a budget less than 150 million dollars
my_movie_list = small_df[(small_df['revenue'] > 1e9) &
(small_df['budget'] < 1.5e8)]
my_movie_list
# Out:
#                                                title release_date  \
# 7000   The Lord of the Rings: The Return of the King   2003-12-01
# 17437   Harry Potter and the Deathly Hallows: Part 2   2011-07-07
# 30700                                        Minions   2015-06-17
# 44009                                Despicable Me 3   2017-06-15
#
#             budget       revenue  runtime  \
# 7000    94000000.0  1.118889e+09    201.0
# 17437  125000000.0  1.342000e+09    130.0
# 30700   74000000.0  1.156731e+09     91.0
# 44009   80000000.0  1.020063e+09     96.0
#
#                                                   genres  year
# 7000   [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...  2003
# 17437  [{'id': 10751, 'name': 'Family'}, {'id': 14, '...  2011
# 30700  [{'id': 10751, 'name': 'Family'}, {'id': 16, '...  2015
# 44009  [{'id': 28, 'name': 'Action'}, {'id': 16, 'nam...  2017

# %%
#Check the data type of the data
print(type(small_df['runtime']))
#Assign the runtime variable to a Series object
runtime = small_df['runtime']
#Print the maximum value of the runtime of movies
print(runtime.max())
#Print the minimum value of the runtime of movies
print(runtime.min())
# Out:
# <class 'pandas.core.series.Series'>
# 1256.0
# 0.0

# %%
#Assign the budget variable to a Series object
budget = small_df['budget']
#Print the mean value of the budget of movies
print(budget.mean())
#Print the median value of the budget of movies
print(budget.median())
# Out:
# 4224578.813474693
# 0.0

# %%
#นAssign the revenue variable to a Series object
revenue = small_df['revenue']
#Find Revenue ขof movies at 90th percentile
revenue.quantile(0.90)
# Out:
# 8267610.399999982

# %%
#Count the number of movies released in each year
small_df['year'].value_counts()
# Out:
# 2014    1974
# 2015    1905
# 2013    1889
# 2012    1722
# 2011    1667
#         ...
# 2020       1
# 1878       1
# 1887       1
# 1893       1
# 1874       1
# Name: year, Length: 136, dtype: int64
